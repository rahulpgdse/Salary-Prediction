# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("expected_ctc.csv")
df = df.drop(["IDX","Applicant_ID"],axis=1)
df.head()
# Out:
#    Total_Experience  Total_Experience_in_field_applied      Department  \
# 0                 0                                  0             NaN
# 1                23                                 14              HR
# 2                21                                 12  Top Management
# 3                15                                  8         Banking
# 4                10                                  5           Sales
#
#                 Role   Industry Organization      Designation  Education  \
# 0                NaN        NaN          NaN              NaN         PG
# 1         Consultant  Analytics            H               HR  Doctorate
# 2         Consultant   Training            J              NaN  Doctorate
# 3  Financial Analyst   Aviation            F               HR  Doctorate
# 4    Project Manager  Insurance            E  Medical Officer       Grad
#
#   Graduation_Specialization University_Grad  ...  Curent_Location  \
# ...

# %%
df.head(5)
# Out:
#    Total_Experience  Total_Experience_in_field_applied      Department  \
# 0                 0                                  0             NaN
# 1                23                                 14              HR
# 2                21                                 12  Top Management
# 3                15                                  8         Banking
# 4                10                                  5           Sales
#
#                 Role   Industry Organization      Designation  Education  \
# 0                NaN        NaN          NaN              NaN         PG
# 1         Consultant  Analytics            H               HR  Doctorate
# 2         Consultant   Training            J              NaN  Doctorate
# 3  Financial Analyst   Aviation            F               HR  Doctorate
# 4    Project Manager  Insurance            E  Medical Officer       Grad
#
#   Graduation_Specialization University_Grad  ...  Curent_Location  \
# ...

# %%
df.tail(5)
# Out:
#        Total_Experience  Total_Experience_in_field_applied   Department  \
# 24995                18                                 13  Engineering
# 24996                12                                  8           HR
# 24997                22                                  8      Banking
# 24998                25                                  8    Marketing
# 24999                 8                                  0      Banking
#
#                   Role    Industry Organization         Designation  \
# 24995  Project Manager  Automobile            I   Assistant Manager
# 24996           Others   Analytics            B          Sr.Manager
# 24997             Head   Insurance            D  Software Developer
# 24998              CEO        BFSI            D   Marketing Manager
# 24999       Consultant  Automobile            P          Sr.Manager
#
#         Education Graduation_Specialization University_Grad  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Total_Experience', 'Total_Experience_in_field_applied', 'Department',
#        'Role', 'Industry', 'Organization', 'Designation', 'Education',
#        'Graduation_Specialization', 'University_Grad',
#        'Passing_Year_Of_Graduation', 'PG_Specialization', 'University_PG',
#        'Passing_Year_Of_PG', 'PHD_Specialization', 'University_PHD',
#        'Passing_Year_Of_PHD', 'Curent_Location', 'Preferred_location',
#        'Current_CTC', 'Inhand_Offer', 'Last_Appraisal_Rating',
#        'No_Of_Companies_worked', 'Number_of_Publications', 'Certifications',
#        'International_degree_any', 'Expected_CTC'],
#       dtype='object')

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Total_Experience', 'Total_Experience_in_field_applied', 'Current_CTC', 'No_Of_Companies_worked', 'Number_of_Publications', 'Certifications', 'International_degree_any', 'Expected_CTC'], float64: ['Passing_Year_Of_Graduation', 'Passing_Year_Of_PG', 'Passing_Year_Of_PHD'], object: ['Department', 'Role', 'Industry', 'Organization', 'Designation', 'Education', 'Graduation_Specialization', 'University_Grad', 'PG_Specialization', 'University_PG', 'PHD_Specialization', 'University_PHD', 'Curent_Location', 'Preferred_location', 'Inhand_Offer', 'Last_Appraisal_Rating']}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Total_Experience                   25000 non-null  int64
#  1   Total_Experience_in_field_applied  25000 non-null  int64
#  2   Department                         22222 non-null  object
#  3   Role                               24037 non-null  object
#  4   Industry                           24092 non-null  object
#  5   Organization                       24092 non-null  object
#  6   Designation                        21871 non-null  object
#  7   Education                          25000 non-null  object
#  8   Graduation_Specialization          18820 non-null  object
#  9   University_Grad                    18820 non-null  object
#  10  Passing_Year_Of_Graduation         18820 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Total_Experience  Total_Experience_in_field_applied  \
# count      25000.000000                       25000.000000
# mean          12.493080                           6.258200
# std            7.471398                           5.819513
# min            0.000000                           0.000000
# 25%            6.000000                           1.000000
# 50%           12.000000                           5.000000
# 75%           19.000000                          10.000000
# max           25.000000                          25.000000
#
#        Passing_Year_Of_Graduation  Passing_Year_Of_PG  Passing_Year_Of_PHD  \
# count                18820.000000        17308.000000         13119.000000
# mean                  2002.193624         2005.153571          2007.396372
# std                      8.316640            9.022963             7.493601
# min                   1986.000000         1988.000000          1995.000000
# ...

# %%
df.hist(figsize=(20,20))
plt.show()

# %%
# Education Field of employees
df['Education'].value_counts()
# Out:
# PG            6326
# Doctorate     6285
# Grad          6209
# Under Grad    6180
# Name: Education, dtype: int64

# %%
# Gender of employees
df['Department'].value_counts()
# Out:
# Marketing         2379
# Analytics/BI      2096
# Healthcare        2062
# Others            2041
# Sales             1991
# HR                1988
# Banking           1952
# Education         1948
# Engineering       1937
# Top Management    1632
# Accounts          1118
# IT-Software       1078
# Name: Department, dtype: int64

# %%
# Employees in the database have several roles on-file
df['Role'].value_counts()
# Out:
# Others                  2248
# Bio statistician        1913
# Analyst                 1892
# Project Manager         1850
# Team Lead               1833
# Consultant              1780
# Business Analyst        1711
# Sales Execituve         1574
# Sales Manager           1427
# Senior Researcher       1236
# Financial Analyst       1182
# CEO                     1149
# Scientist               1139
# Head                    1108
# Associate                767
# Data scientist           363
# Principal Analyst        275
# Area Sales Manager       134
# Senior Analyst           128
# Researcher               123
# Sr. Business Analyst     114
# Professor                 33
# Research Scientist        33
# Lab Executuve             25
# Name: Role, dtype: int64

# %%
print(df.loc[df["Current_CTC"]==0])
# Out:
#        Total_Experience  Total_Experience_in_field_applied Department Role  \
# 0                     0                                  0        NaN  NaN
# 13                    0                                  0        NaN  NaN
# 140                   0                                  0        NaN  NaN
# 150                   0                                  0        NaN  NaN
# 176                   0                                  0        NaN  NaN
# ...                 ...                                ...        ...  ...
# 24850                 0                                  0        NaN  NaN
# 24903                 0                                  0        NaN  NaN
# 24926                 0                                  0        NaN  NaN
# 24959                 0                                  0        NaN  NaN
# 24970                 0                                  0        NaN  NaN
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 86853

# %%
df["Passing_Year_Of_PHD"].replace(to_replace = np.nan, value = 0,inplace=True)
df["University_PHD"].replace(to_replace = np.nan, value = "Indian",inplace=True)
df["PHD_Specialization"].replace(to_replace = np.nan, value = "others",inplace=True)
df["Passing_Year_Of_PG"].replace(to_replace = np.nan, value = 0,inplace=True)
df["PG_Specialization"].replace(to_replace = np.nan, value = "others",inplace=True)
df["University_PG"].replace(to_replace = np.nan, value = "Indian",inplace=True)
df["Graduation_Specialization"].replace(to_replace = np.nan, value = "others",inplace=True)
df["University_Grad"].replace(to_replace = np.nan, value = "Indian",inplace=True)
df["Passing_Year_Of_Graduation"].replace(to_replace = np.nan, value = 0,inplace=True)
df["Designation"].replace(to_replace = np.nan, value = "others",inplace=True)
df["Department"].replace(to_replace = np.nan, value = "others",inplace=True)
df["Role"].replace(to_replace = np.nan, value = "others",inplace=True)
df["Industry"].replace(to_replace = np.nan, value = "others",inplace=True)
df["Organization"].replace(to_replace = np.nan, value = "others",inplace=True)
df["Last_Appraisal_Rating"].replace(to_replace = np.nan, value = "others",inplace=True)

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Total_Experience                     0
# PHD_Specialization                   0
# International_degree_any             0
# Certifications                       0
# Number_of_Publications               0
# No_Of_Companies_worked               0
# Last_Appraisal_Rating                0
# Inhand_Offer                         0
# Current_CTC                          0
# Preferred_location                   0
# Curent_Location                      0
# Passing_Year_Of_PHD                  0
# University_PHD                       0
# Passing_Year_Of_PG                   0
# Total_Experience_in_field_applied    0
# University_PG                        0
# PG_Specialization                    0
# Passing_Year_Of_Graduation           0
# University_Grad                      0
# Graduation_Specialization            0
# Education                            0
# Designation                          0
# Organization                         0
# Industry                             0
# ...

# %%
#distribution  of salary
plt.figure(figsize = (14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(df.Current_CTC )
plt.subplot(1, 2, 2)
sns.distplot(df.Current_CTC , bins = 20)
plt.show()
# Out:
# C:\Users\adity\anaconda3\envs\AntonioEnv\lib\site-packages\ipykernel_launcher.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
# Plot variance of years of experience
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['Total_Experience_in_field_applied'], df['Current_CTC'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3780\3814394127.py in <module>
#       3 height = 10
#       4 plt.figure(figsize=(width, height))
# ----> 5 sns.residplot(df['Total_Experience_in_field_applied'], df['Current_CTC'])
#       6 plt.show()
#
# TypeError: residplot() takes from 0 to 1 positional arguments but 2 were given

# %%
# Plot regression line on years of experience
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x='Total_Experience', y='Current_CTC', data=df, line_kws={'color':'black'})
# Out:
# <AxesSubplot:xlabel='Total_Experience', ylabel='Current_CTC'>

# %%
# Plot variance of years of experience
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df['Total_Experience'], df['Current_CTC'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3780\1715822780.py in <module>
#       3 height = 10
#       4 plt.figure(figsize=(width, height))
# ----> 5 sns.residplot(df['Total_Experience'], df['Current_CTC'])
#       6 plt.show()
#
# TypeError: residplot() takes from 0 to 1 positional arguments but 2 were given

# %%
# Plot boxplots for companyId
width = 16
height = 8
var = 'Organization'
data = pd.concat([df['Current_CTC'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(width, height))
fig = sns.boxplot(x=var, y='Current_CTC', data=df)
plt.xticks(rotation=90)

# %%
f, ax = plt.subplots(figsize=(12, 9));
sns.barplot('Current_CTC','Role',data=df)

# %%
a = df["Current_CTC"][:10].plot.barh(figsize=(16,10))

# %%
df["Current_CTC"].hist()
# Out:
# <AxesSubplot:>

# %%
#Calculate correlations
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
# Heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(corr,
            vmax=.5,
            mask=mask,
            # annot=True, fmt='.2f',
            linewidths=.2, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Total_Experience  Total_Experience_in_field_applied  \
# 0                 0                                  0
# 1                23                                 14
# 2                21                                 12
# 3                15                                  8
# 4                10                                  5
#
#    Passing_Year_Of_Graduation  Passing_Year_Of_PG  Passing_Year_Of_PHD  \
# 0                      2020.0                 0.0                  0.0
# 1                      1988.0              1990.0               1997.0
# 2                      1990.0              1992.0               1999.0
# 3                      1997.0              1999.0               2005.0
# 4                      2004.0              2006.0               2010.0
#
#    Current_CTC  No_Of_Companies_worked  Number_of_Publications  \
# 0            0                       0                       0
# 1      2702664                       2                       4
# ...

# %%
df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
#Correlation Matrix
g=sns.heatmap(df[["Total_Experience_in_field_applied","Current_CTC","Graduation_Specialization"]].corr(),annot=True ,fmt=".2f", cmap="coolwarm")

# %%
#Time series view
plt.figure(figsize=(20,8))
df.groupby(['Total_Experience'])['Expected_CTC'].sum().plot(kind='line')
plt.show()

# %%
Corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(data=corr,vmin=0, vmax=1, cmap="YlGnBu",  square=True)
plt.show()

# %%
# checking variables
for i in df.columns:
    if df[i].nunique() < 10:
        print(f'The column "{i}" is __{df[i].dtype}__ \nhas __{df[i].nunique()}__ unique values: \n{df[i].value_counts()}')
        print(10*'==')
    else:
        print(f'The column "{i}" is __{df[i].dtype}__ \nhas __{df[i].nunique()}__ unique values')
        print(10*'==')
# Out:
# The column "Total_Experience" is __int64__
# has __26__ unique values
# ...
# The column "Total_Experience_in_field_applied" is __int64__
# has __26__ unique values
# ...
# The column "Department" is __object__
# has __13__ unique values
# ...
# The column "Role" is __object__
# has __25__ unique values
# ...
# The column "Industry" is __object__
# has __12__ unique values
# ...
# The column "Organization" is __object__
# has __17__ unique values
# ...
# The column "Designation" is __object__
# has __19__ unique values
# ...
# The column "Education" is __object__
# has __4__ unique values:
# PG            6326
# Doctorate     6285
# Grad          6209
# Under Grad    6180
# Name: Education, dtype: int64
# ...
# The column "Graduation_Specialization" is __object__
# has __12__ unique values
# ...
# The column "University_Grad" is __object__
# has __14__ unique values
# ...
# The column "Passing_Year_Of_Graduation" is __float64__
# has __36__ unique values
# ...
# The column "PG_Specialization" is __object__
# has __12__ unique values
# ...

# %%
plt.scatter(df.Total_Experience_in_field_applied,df.Expected_CTC)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
cols = ['Department', 'Role', 'Industry', 'Organization', 'Designation',
       'Education', 'Graduation_Specialization', 'University_Grad',
       'Passing_Year_Of_Graduation', 'PG_Specialization', 'University_PG',
       'Passing_Year_Of_PG', 'PHD_Specialization', 'University_PHD',
       'Passing_Year_Of_PHD', 'Curent_Location', 'Preferred_location', 'Inhand_Offer', 'Last_Appraisal_Rating',
       'No_Of_Companies_worked', 'Number_of_Publications', 'Certifications',
       'International_degree_any']



df[cols] = df[cols].apply(LabelEncoder().fit_transform)



df.head()
# Out:
#    Total_Experience  Total_Experience_in_field_applied  Department  Role  \
# 0                 0                                  0          12    24
# 1                23                                 14           5     6
# 2                21                                 12          11     6
# 3                15                                  8           2     8
# 4                10                                  5          10    14
#
#    Industry  Organization  Designation  Education  Graduation_Specialization  \
# 0        11            16           18          2                          0
# 1         0             7            5          0                          2
# 2        10             9           18          0                         10
# 3         2             5            5          0                          6
# 4         6             4            8          1                         10
#
# ...

# %%
categorical_features=[ x for x in df.columns if df[x].dtype == 'O']
categorical_features
# Out:
# []

# %%
#finding count of different elements in the column

for x in categorical_features:
    a = df[x].value_counts()
    print(a)

# %%
numerical_features = [x for x in df.columns if x not in categorical_features]
numerical_features
# Out:
# ['Total_Experience',
#  'Total_Experience_in_field_applied',
#  'Department',
#  'Role',
#  'Industry',
#  'Organization',
#  'Designation',
#  'Education',
#  'Graduation_Specialization',
#  'University_Grad',
#  'Passing_Year_Of_Graduation',
#  'PG_Specialization',
#  'University_PG',
#  'Passing_Year_Of_PG',
#  'PHD_Specialization',
#  'University_PHD',
#  'Passing_Year_Of_PHD',
#  'Curent_Location',
#  'Preferred_location',
#  'Current_CTC',
#  'Inhand_Offer',
#  'Last_Appraisal_Rating',
#  'No_Of_Companies_worked',
#  'Number_of_Publications',
#  'Certifications',
#  'International_degree_any',
#  'Expected_CTC']

# %%
from pandas import factorize

# %%
# corelation value
labels, categories = factorize(df["Expected_CTC"])
df["Designation"] = labels
df["Designation"].corr(df["Expected_CTC"])
# Out:
# -0.004798571302144544

# %%
labels, categories = factorize(df["Designation"])
df["Certifications"] = labels
df["Number_of_Publications"].corr(df["Designation"])
# Out:
# 0.0030449293046329123

# %%
df.groupby(['Total_Experience','Department'])['Expected_CTC'].sum().sort_values(ascending=False)
# Out:
# Total_Experience  Department
# 0                 12            528464569
# 19                9             376828188
# 17                11            342869598
# 22                11            327655625
# 24                1             325005619
#                                   ...
# 5                 7              36715254
# 1                 0              32385472
#                   7              30765922
# 3                 7              29673169
# 2                 7              26771716
# Name: Expected_CTC, Length: 321, dtype: int64

# %%
#skewness and kurtosis
print("Skewness: %f" % df['Expected_CTC'].skew())
print("Kurtosis: %f" % df['Expected_CTC'].kurt())
# Out:
# Skewness: 0.331972
# Kurtosis: -0.500660

# %%
print("Skewness: %f" % df['Industry'].skew())
print("Kurtosis: %f" % df['Industry'].kurt())
# Out:
# Skewness: 0.025820
# Kurtosis: -1.194177

# %%
# corelation value
labels, categories = factorize(df["Expected_CTC"])
df["Department"] = labels
df["Expected_CTC"].corr(df["Expected_CTC"])
# Out:
# 1.0

# %%
#feature to Feature relation

corr = df.drop('Expected_CTC', axis=1).corr() # We already examined total revenue correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder,MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestRegressor

# %%
str_col=['Total_Experience','No_Of_Companies_worked','Expected_CTC']
le=LabelEncoder()
for col in str_col:
    df[col]=le.fit_transform(df[col].values)

# %%
sc=MinMaxScaler()
num_col=list(df.select_dtypes(exclude = ['object']).drop(columns=['Expected_CTC',]).columns)
df_scaled=sc.fit_transform(df[num_col].values)

# %%
df_scaled=pd.DataFrame(df_scaled,columns=num_col)
df_scaled.head()
# Out:
#    Total_Experience  Total_Experience_in_field_applied  Department      Role  \
# 0              0.00                               0.00    0.000000  1.000000
# 1              0.92                               0.56    0.000040  0.250000
# 2              0.84                               0.48    0.000080  0.250000
# 3              0.60                               0.32    0.000120  0.333333
# 4              0.40                               0.20    0.000161  0.583333
#
#    Industry  Organization  Designation  Education  Graduation_Specialization  \
# 0  1.000000        1.0000     0.000000   0.666667                   0.000000
# 1  0.000000        0.4375     0.000040   0.000000                   0.181818
# 2  0.909091        0.5625     0.000080   0.000000                   0.909091
# 3  0.181818        0.3125     0.000120   0.000000                   0.545455
# 4  0.545455        0.2500     0.000161   0.333333                   0.909091
#
# ...

# %%
df[num_col]
# Out:
#        Total_Experience  Total_Experience_in_field_applied  Department  Role  \
# 0                     0                                  0           0    24
# 1                    23                                 14           1     6
# 2                    21                                 12           2     6
# 3                    15                                  8           3     8
# 4                    10                                  5           4    14
# ...                 ...                                ...         ...   ...
# 24995                18                                 13       24908    14
# 24996                12                                  8       24909    11
# 24997                22                                  8       24910     9
# 24998                25                                  8       24911     5
# 24999                 8                                  0       24912     6
#
# ...

# %%
# Adding test and traing flag so that we can split train/test data
df['tst']=0
df['tst']=1

# %%
train=df[df.tst==0]
test=df[df.tst==1]

# %%
train=train.drop(columns=['tst','Department'],axis=1)

# %%
test=test.drop(columns=['tst','Expected_CTC','Department'],axis=1)

# %%
X=train.columns.drop('Expected_CTC')
y=train.Expected_CTC
X
# Out:
# Index(['Total_Experience', 'Total_Experience_in_field_applied', 'Role',
#        'Industry', 'Organization', 'Designation', 'Education',
#        'Graduation_Specialization', 'University_Grad',
#        'Passing_Year_Of_Graduation', 'PG_Specialization', 'University_PG',
#        'Passing_Year_Of_PG', 'PHD_Specialization', 'University_PHD',
#        'Passing_Year_Of_PHD', 'Curent_Location', 'Preferred_location',
#        'Current_CTC', 'Inhand_Offer', 'Last_Appraisal_Rating',
#        'No_Of_Companies_worked', 'Number_of_Publications', 'Certifications',
#        'International_degree_any'],
#       dtype='object')

# %%
train[X].var().sort_values(ascending=False)
# Out:
# Total_Experience                    NaN
# Total_Experience_in_field_applied   NaN
# Role                                NaN
# Industry                            NaN
# Organization                        NaN
# Designation                         NaN
# Education                           NaN
# Graduation_Specialization           NaN
# University_Grad                     NaN
# Passing_Year_Of_Graduation          NaN
# PG_Specialization                   NaN
# University_PG                       NaN
# Passing_Year_Of_PG                  NaN
# PHD_Specialization                  NaN
# University_PHD                      NaN
# Passing_Year_Of_PHD                 NaN
# Curent_Location                     NaN
# Preferred_location                  NaN
# Current_CTC                         NaN
# Inhand_Offer                        NaN
# Last_Appraisal_Rating               NaN
# No_Of_Companies_worked              NaN
# Number_of_Publications              NaN
# ...

# %%
X = df[['Education','Total_Experience','Organization']]
Y = df['Expected_CTC']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((17500, 3), (7500, 3), (17500,), (7500,))

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train_scaled,Y_train)
# Out:
# LinearRegression()

# %%
# View coefficients of linear regression object
print(lr.intercept_)
print(lr.coef_)
# Out:
# 12447.9972
# [-1923.57519545  6001.48671816   -30.83535964]

# %%
#Slopes/Coefficients
m = lr.coef_
print("slopes  : ",m[0].round(2))
print("slopes  : ",m[1].round(2))

#Intercept
c = lr.intercept_
print("Intercept is : ",c.round(2))
# Out:
# slopes  :  -1923.58
# slopes  :  6001.49
# Intercept is :  12448.0

# %%
Y_pred = lr.predict(X_test_scaled)

# %%
Y_pred
# Out:
# array([ 9732.42428075, 12758.58600539, 18570.76615236, ...,
#        14511.21623641, 15900.58265938,  6540.12770313])

# %%
#compre actual vs predicted o/p
dict={'Actual Output':Y_test,'Predicted output':Y_pred}
#convert dictionary into dataframe
df1=pd.DataFrame(dict)
df1
# Out:
#        Actual Output  Predicted output
# 21492           5693       9732.424281
# 9488            9670      12758.586005
# 16933          16669      18570.766152
# 12604           2244       6507.951334
# 8222            1345       6609.733448
# ...              ...               ...
# 13410           6713       7419.069322
# 13158          21196      11931.126577
# 3552           13259      14511.216236
# 23203          21492      15900.582659
# 2410            3029       6540.127703
#
# [7500 rows x 2 columns]

# %%
#Mean Squared Error 1/n*sum(Y-Y-pred)**2
from sklearn.metrics import mean_squared_error
print("MSE: ",mean_squared_error(Y_test,Y_pred))
# Out:
# MSE:  11914771.154343156

# %%
#Root mean squred error
mse=mean_squared_error(Y_test,Y_pred)
rmse=np.sqrt(mse)
print("Root Mean Sqaured Error : ",rmse)
# Out:
# Root Mean Sqaured Error :  3451.7779700240217

# %%
#R2--Score 
#Check model is perfect or not
from sklearn.metrics import r2_score
print("R2-score : ",r2_score(Y_test,Y_pred))
# Out:
# R2-score :  0.7712128103467416

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print("MAE",mean_absolute_error(Y_test,Y_pred))
print("MSE",mean_squared_error(Y_test,Y_pred))
print("R2 score",r2_score(Y_test,Y_pred))
# Out:
# MAE 2636.8755612090786
# MSE 11914771.154343156
# R2 score 0.7712128103467416

# %%
#Find Error or Residue
residual=Y_test-Y_pred
print(residual.head())
# Out:
# 21492   -4039.424281
# 9488    -3088.586005
# 16933   -1901.766152
# 12604   -4263.951334
# 8222    -5264.733448
# Name: Expected_CTC, dtype: float64

# %%
#Create a Dictionary:
dic={'Y_pred' :Y_pred,'residual' : residual}
df2=pd.DataFrame(dic)
df2.head()
# Out:
#              Y_pred     residual
# 21492   9732.424281 -4039.424281
# 9488   12758.586005 -3088.586005
# 16933  18570.766152 -1901.766152
# 12604   6507.951334 -4263.951334
# 8222    6609.733448 -5264.733448

# %%
#Visualise scatterplot between Y_pred & residual means
#here input x=Y_pred & output y=residual because residual depends on Y_pred value.
sns.scatterplot(data=df2,x='Y_pred',y='residual')
plt.show()

# %%
#create Histogram(Frequency graph):
#here ngative skewness
sns.histplot(residual)
plt.show()

# %%
#Distplot()
sns.distplot(residual)
plt.show()
# Out:
# C:\Users\adity\anaconda3\envs\AntonioEnv\lib\site-packages\ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
#Find Skewness:
residual.skew()
# Out:
# 0.09524441015340776

# %%
# View shape and features of all datasets to be used
print("Number of test samples:", X_test.shape, "\nwith these features:\n", X_test.columns)
print("\nNumber of training samples:", X_train.shape, "\nwith these features:\n", X_train.columns)
print("\nNumber of test salaries:", Y_test.shape)
print("Number of training salaries:", Y_train.shape)
# Out:
# Number of test samples: (7500, 3)
# with these features:
#  Index(['Education', 'Total_Experience', 'Organization'], dtype='object')
#
# Number of training samples: (17500, 3)
# with these features:
#  Index(['Education', 'Total_Experience', 'Organization'], dtype='object')
#
# Number of test salaries: (7500,)
# Number of training salaries: (17500,)

# %%
from sklearn.ensemble import RandomForestRegressor

#Create a Gaussian Classifier
rf=RandomForestRegressor(n_estimators=10)

#Train the model using the training sets y_pred=clf.predict(X_test)
rf.fit(X_train,Y_train)

y_pred_1=rf.predict(X_test)

# %%
y_pred_1
# Out:
# array([ 7186.07833052, 16854.48392496, 16413.1502381 , ...,
#        13823.23035408, 15218.00934343,  2914.50614316])

# %%
#compre actual vs predicted o/p
dict={'Actual Output':Y_test,'Predicted output':y_pred_1}
#convert dictionary into dataframe
df_4=pd.DataFrame(dict)
df_4
# Out:
#        Actual Output  Predicted output
# 21492           5693       7186.078331
# 9488            9670      16854.483925
# 16933          16669      16413.150238
# 12604           2244       2286.250714
# 8222            1345       3780.907713
# ...              ...               ...
# 13410           6713       8348.215238
# 13158          21196      15248.207595
# 3552           13259      13823.230354
# 23203          21492      15218.009343
# 2410            3029       2914.506143
#
# [7500 rows x 2 columns]

# %%
#Mean Squared Error 1/n*sum(Y-Y-pred)**2
from sklearn.metrics import mean_squared_error
print("MSE: ",mean_squared_error(Y_test,y_pred_1))
# Out:
# MSE:  7188150.544894743

# %%
mse=mean_squared_error(Y_test,y_pred_1)
rmse=np.sqrt(mse)
print("Root Mean Sqaured Error : ",rmse)
# Out:
# Root Mean Sqaured Error :  2681.0726481941406

# %%
#R2--Score 
#Check model is perfect or not
from sklearn.metrics import r2_score
print("R2-score : ",r2_score(Y_test,y_pred_1))
# Out:
# R2-score :  0.8619732816797295

# %%
#Find Error or Residue
residual=Y_test-y_pred_1
print(residual.head())
# Out:
# 21492   -1493.078331
# 9488    -7184.483925
# 16933     255.849762
# 12604     -42.250714
# 8222    -2435.907713
# Name: Expected_CTC, dtype: float64

# %%
#Create a Dictionary:
dic={'Y_pred' :y_pred_1,'residual' : residual}
df_5=pd.DataFrame(dic)
df_5.head()
# Out:
#              Y_pred     residual
# 21492   7186.078331 -1493.078331
# 9488   16854.483925 -7184.483925
# 16933  16413.150238   255.849762
# 12604   2286.250714   -42.250714
# 8222    3780.907713 -2435.907713

# %%
#Visualise scatterplot between Y_pred & residual means
#here input x=Y_pred & output y=residual because residual depends on Y_pred value.
sns.scatterplot(data=df_5,x=y_pred_1,y='residual')
plt.show()

# %%
sns.distplot(residual)
plt.show()
# Out:
# C:\Users\adity\anaconda3\envs\AntonioEnv\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.svm import SVR

sv = SVR(kernel='rbf')
sv.fit(X_train_scaled,Y_train)

y_pred = sv.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([11520.3204228 , 12339.63402108, 14078.99246861, ...,
#        13338.63762989, 13013.88038503, 11113.47932917])

# %%
#compre actual vs predicted o/p
dict={'Actual Output':Y_test,'Predicted output':y_pred}
#convert dictionary into dataframe
df_2=pd.DataFrame(dict)
df_2
# Out:
#        Actual Output  Predicted output
# 21492           5693      11520.320423
# 9488            9670      12339.634021
# 16933          16669      14078.992469
# 12604           2244      10570.658269
# 8222            1345      11027.742936
# ...              ...               ...
# 13410           6713      11158.703169
# 13158          21196      12110.788250
# 3552           13259      13338.637630
# 23203          21492      13013.880385
# 2410            3029      11113.479329
#
# [7500 rows x 2 columns]

# %%
#Mean Squared Error 1/n*sum(Y-Y-pred)**2
from sklearn.metrics import mean_squared_error
print("MSE: ",mean_squared_error(Y_test,y_pred))
# Out:
# MSE:  36253766.18287494

# %%
mse=mean_squared_error(Y_test,y_pred)
rmse=np.sqrt(mse)
print("Root Mean Sqaured Error : ",rmse)
# Out:
# Root Mean Sqaured Error :  6021.110045736994

# %%
#R2--Score 
#Check model is perfect or not
from sklearn.metrics import r2_score
print("R2-score : ",r2_score(Y_test,y_pred))
# Out:
# R2-score :  0.30385593043448134

# %%
#Find Error or Residue
residual=Y_test-y_pred
print(residual.head())
# Out:
# 21492   -5827.320423
# 9488    -2669.634021
# 16933    2590.007531
# 12604   -8326.658269
# 8222    -9682.742936
# Name: Expected_CTC, dtype: float64

# %%
#Create a Dictionary:
dic={'Y_pred' :y_pred,'residual' : residual}
df_3=pd.DataFrame(dic)
df_3.head()
# Out:
#              Y_pred     residual
# 21492  11520.320423 -5827.320423
# 9488   12339.634021 -2669.634021
# 16933  14078.992469  2590.007531
# 12604  10570.658269 -8326.658269
# 8222   11027.742936 -9682.742936

# %%
#Visualise scatterplot between Y_pred & residual means
#here input x=Y_pred & output y=residual because residual depends on Y_pred value.
sns.scatterplot(data=df_3,x=y_pred,y='residual')
plt.show()

# %%
sns.distplot(residual)
plt.show()
# Out:
# C:\Users\adity\anaconda3\envs\AntonioEnv\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
